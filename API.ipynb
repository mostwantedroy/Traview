# %%
from google.colab import drive

# %%
from google.colab import drive
drive.mount('/gdrive',force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
# !ls "/gdrive/My Drive"
# Out:
#  포트폴리오	  att_table_서울1.csv   data		  leports_table.csv
# '제목없는 폴더'  'Colab Notebooks'      inmun_table.csv   nature_table.csv

# %%
import pandas as pd

word_table = pd.read_csv("/gdrive/My Drive/att_table_서울1.csv", delimiter=",",encoding='utf-8')
print(len(word_table))
word_table.head()
# Out:
# 890
#       loid        id              name  star    num      type
# 0   294197   1169465           N 서울 타워    40   9452  전망대 & 타워
# 1   294197   2194168             서울메트로    45  12703  공공 교통시스템
# 2  2024866   2041648             서울대공원    45    267        가든
# 3   294197   1519813             한강 공원    45   1569        공원
# 4   294197  10725552  서울이스케이프룸 - 강남1호점    50    426     탈출 게임

# %%
ttype=['전망대 & 타워', '공공 교통시스템', '가든', '공원', '탈출 게임', '인근 지역', '유서 깊은 산책로', '놀이공원 & 테마파크', '역사적인 장소', '국립공원', '전문 박물관', '탈출 게임', '인근 지역', '벼룩시장 & 재래시장', '대학 & 학교', '벼룩시장 & 재래시장', '공공기관 건물', '인근 지역', '가든', '문화 행사', '가든', '인근 지역', '묘지', '즐길거리 & 랜드마크', '종교적인 장소', '건축물', '역사적인 장소', '놀이터', '전망대 & 타워', '종교적인 장소', '시즌별 폭죽놀이', '아트뮤지엄', '관광 투어', '쇼핑몰', '건축물', '관광 투어', '아트뮤지엄', '아트뮤지엄', '역사적인 장소', '공원', '수족관', '역사박물관', '전망대 & 타워', '전문 박물관', '공공 교통시스템', '공원', '고대 유적', '공원', '종교적인 장소', '공원', '경전철 서비스', '종교적인 장소', '버스투어', '탈출 게임', '즐길거리 & 랜드마크', '즐길거리 & 랜드마크', '즐길거리 & 랜드마크', '건축물', '교회 & 성당', '공원', '도보 여행', '벼룩시장 & 재래시장', '영화극장', '온열 스파', '아레나 & 경기장', '전차', '문화 행사', '공원', '공공 교통시스템', '탈출 게임', '특산물 & 기념품 가게', '인근 지역', '산', '스포츠 컴플렉스', '공원', '관광 투어', '역사적인 장소', '산', '인근 지역', '즐길거리 & 랜드마크', '기념비 및 동상', '도보 여행', '가든', '전문 박물관', '관광 투어', '인근 지역', '전문 박물관', '관광 투어', '팩토리 아울렛', '역사박물관', '아트뮤지엄', '역사적인 장소', '도보 여행', '브리지', '유서 깊은 산책로', '인근 지역', '즐길거리 & 랜드마크', '극장 & 공연', '역사적인 장소', '즐길거리 & 랜드마크', '도서관', '건축물', '댄스 클럽 & 디스코', '아트뮤지엄', '바, 클럽 & 펍 투어', '극장 & 공연', '관광 투어', '전문 박물관', '백화점', '스파', '역사적인 장소', '종교적인 장소', '놀이공원 & 테마파크', '공원', '특산물 & 기념품 가게', '벼룩시장 & 재래시장', '쇼핑몰', '백화점', '스파', '바 & 클럽', '산', '기념비 및 동상', '해변', '도서관', '요리 교실', '카지노', '시티 투어', '관광센터', '종교적인 장소', '관광 투어', '백화점', '물길', '기타 야외 활동', '즐길거리 & 랜드마크', '공원', '역사적인 장소', '공공기관 건물', '게임 & 엔터테인먼트 센터', '게임 & 엔터테인먼트 센터', '공원', '보트 투어', '전문 박물관', '아트뮤지엄', '관광 투어', '벼룩시장 & 재래시
파', '세그웨이 투어', '특산물 & 기념품 가게', '시어터', '전문 박물관', '역사박물관', '시티 투어', '스키 & 스노보드 지역', '영화극장', '역사적인 장소', '특산물 & 기념품 가게', '전문 박물관', '특산물 & 기념품 가게', '종교적인 장소', '산림', '인근 지역', '관광 투어', '역사적인 장소', '교회 & 성당', '아레나 & 경기장', '공원', '관광 투어', '하이킹 & 캠핑 투어', '역사적인 장소', '전문 박물관', '역사박물관', '공원', '특산물 & 기념품 가게', '쇼핑몰', '영화극장', '게임 & 엔터테인먼트 센터', '게임 & 엔터테인먼트 센터', '스파', '역사박물관', '푸드 투어', '전문 박물관', '관광 투어', '게임 & 엔터테인먼트 센터', '바 & 클럽', '워터파크', '영화극장', '즐길거리 & 랜드마크', '게임 & 엔터테인먼트 센터', '바 & 클럽', '워터파크', '영화극장', '즐길거리 & 랜드마크', '즐길거리 & 랜드마크', '공원', '아트뮤지엄', '극장 & 공연', '기타', '역사박물관', '인근 지역', '벼룩시장 & 재래시장', '게임 & 엔터테인먼트 센터', '특산물 & 기념품 가게', '스파', '스파', '워터파크', '유서 깊은 산책로', '역사박물관', '게임 & 엔터테인먼트 센터', '도보 여행', '산', '역사적인 장소', '관광 투어', '관광 투어', '스파', '특산물 & 기념품 가게', '스파', '관광 투어', '즐길거리 & 랜드마크', '관광 투어', '기념비 및 동상', '특산물 & 기념품 가게', '관광 투어', '스파', '스파', '게임 & 엔터테인먼트 센터', '쇼핑몰', '스파', '스파', '게임 & 엔터테인먼트 센터', '특산물 & 기념품 가게', '스파', '자전거 투어', '자연 & 야생 서식지 투어', '백화점', '탈출 게임', '영화 & TV 투어', '놀이공원 & 테마파크', '카지노', '백화점', '바 & 클럽', '영화극장', '바 & 클럽', '관광 투어', '특산물 & 기념품 가게', '바 & 클럽', '백화점', '팩토리 아울렛', '과학박물관', '극장 & 공연', '역사적인 장소', '어린이 박물관', '보트 투어', '해변', '영화극장', '시어터', '극장 & 공연', '벼룩시장 & 재래시장', '공원', '스파', '쇼핑몰', '공원', '바 & 클럽', '종교적인 장소', '군사 기지 및 시설', '스키 & 스노보드 지역', '전문 박물관', '역사박물관', '전문 박물관', '역사박물관', '시어터', '탈출 게임', '스파', '스파', '워터파크', '푸드 투어', '도보 여행', '시티 투어', '전문 박물관', '즐길거리 & 랜드마크', '공원', '스파', '장비 대여', '푸드 투어', '문화체험 투어', '게임 & 엔터테인먼트 센터', '아트뮤지엄', '자연사 박물관', '문화체험 투어', '게임 & 엔터테인먼트 센터', '아트뮤지엄', '자연사 박물관', '목장', '쇼핑몰', '놀이공원 & 테마파크', '역사박물관', '스키 & 스노보드 지역', '특산물 & 기념품 가게', '종교적인 장소', '역사박물관', '역사적인 장소', '역사적인 장소', '전문 박물관', '놀이공원 & 테마파크', '특산물 & 기념품 가게', '카약 & 카누', '스파', '역사적인 장소', '도심', '극장 & 공연', '백화점', '전문 박물관', '역사박물관', '공원', '브리지', '인근 지역', '벼룩시장 & 재래시장', '인근 지역', '요리 교실', '게임 & 엔터테인먼트 센터', '극장 & 공연', '관광 투어', '놀이공원 & 테마파크', '물길', '특산
 & 랜드마크', '백화점', '도심', '기념비 및 동상', '공원', '즐길거리 & 랜드마크', '백화점', '인근 지역', '도심', '관광센터', '전망대 & 타워', '인근 지역', '게임 & 엔터테인먼트 센터', '아트갤러리', '바 & 클럽', '스파', '스파', '바 & 클럽', '전문 박물관', '관광 투어', '역사박물관', '묘지', '요리 교실', '역사적인 장소', '조깅로 & 트랙', '아트뮤지엄', '기타 야외 활동']

# %%
import pandas as pd

word_table = pd.read_csv("/gdrive/My Drive/final_att_table_서울.csv", delimiter=",",encoding='utf-8')
print(len(word_table))
word_table.head()
# Out:
# 281
#       loid       id     name  star    num         type
# 0   294197  1169465  N 서울 타워    40   9452     전망대 & 타워
# 1   294197  2194168    서울메트로    45  12703     공공 교통시스템
# 2  2024866  2041648    서울대공원    45    267           가든
# 3   294197  1046419      청계천    45   3941    유서 깊은 산책로
# 4  2024866  1868571     서울랜드    40    127  놀이공원 & 테마파크

# %%
wordd=list(word_table['num'])

# %%
from collections import Counter
Counter(wordd)
# Out:
# Counter({1: 7,
#          2: 11,
#          3: 9,
#          4: 16,
#          5: 10,
#          6: 21,
#          7: 2,
#          8: 10,
#          9: 11,
#          10: 6,
#          11: 9,
#          12: 6,
#          13: 4,
#          14: 4,
#          15: 1,
#          16: 4,
#          17: 3,
#          18: 6,
#          19: 1,
#          20: 4,
#          21: 2,
#          22: 2,
#          23: 2,
#          24: 3,
#          25: 1,
#          26: 4,
#          28: 2,
#          29: 3,
#          30: 2,
#          31: 3,
#          32: 4,
#          33: 1,
#          34: 3,
#          35: 1,
#          36: 2,
#          38: 2,
#          39: 2,
#          41: 1,
#          42: 1,
#          44: 3,
#          46: 1,
#          47: 2,
#          48: 2,
#          49: 2,
#          50: 3,
#          51: 1,
#          54: 1,
#          59: 3,
#          60: 2,
#          61: 1,
#          63: 1,
#          66: 1,
#          69: 1,
#          77: 2,
#          78: 1,
# ...

# %%
word_table['type'] = ttype

# %%
word_table.to_csv('att_table_서울1.csv',index=False,encoding='utf-8')
from google.colab import files
files.download('att_table_서울1.csv')

# %%
from google.colab import drive
drive.mount('/gdrive',force_remount=True)
# !ls /gdrive/My\ Drive/
word_table.to_csv('/gdrive/My Drive/att_table_서울1.csv',index=False,encoding='utf-8')
# !ls /gdrive/My\ Drive/
# Out:
# Mounted at /gdrive
#  포트폴리오	  att_table_서울1.csv   data		  leports_table.csv
# '제목없는 폴더'  'Colab Notebooks'      inmun_table.csv   nature_table.csv
#  포트폴리오	  att_table_서울1.csv   data		  leports_table.csv
# '제목없는 폴더'  'Colab Notebooks'      inmun_table.csv   nature_table.csv

# %%
word = word_table['name']
import re
word2 = []
for i in word:
    word2.append(i.replace(' ',''))

# %%
word[0]='서울타워'
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
word[0]
# Out:
# '서울타워'

# %%
import requests
import json

data = []
contentid = []
addres = []
title = []

apikey = 'slRBmmH1bnn5k5JrVSIOZTtcwaaLogLUgRmgUgmeFLfAG0kdXYpY0A/WLlULnGXGubqwARlwvffhArbMqKdyhg=='
try:
  for i in word:
      
      api=('http://api.visitkorea.or.kr/openapi/service/rest/KorService/searchKeyword?ServiceKey='+apikey+'&keyword={}&MobileOS=ETC&MobileApp=AppTest&_type=json').format(i)

    # dict2 = json.loads(json_val)
      r = requests.get(api)
      all_data = json.loads(r.text)
      data.append(all_data)
except:
  pass
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-18-3245d694438a> in <module>()
#      15    # dict2 = json.loads(json_val)
#      16     r = requests.get(api)
# ---> 17     all_data = json.loads(r.text)
#      18     data.append(all_data)
#      19
#
# /usr/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# /usr/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
# ...

# %%
data[0]['response']['body']['items']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-e8bd323c3626> in <module>()
# ----> 1 data[0]['response']['body']['items']
#
# KeyError: 'body'

# %%
de = []
try:
  for i in range(0,len(data),1):
      if data[i]['response']['body']['items']=='':
          de.append(i)
except:
  pass

# %%
len(de)
# Out:
# 609

# %%
## tour API에 없는 관광지 역소팅

de.sort(reverse=True)
de
# Out:
# [825,
#  824,
#  823,
#  822,
#  821,
#  820,
#  819,
#  818,
#  817,
#  816,
#  815,
#  814,
#  813,
#  812,
#  811,
#  810,
#  808,
#  807,
#  806,
#  805,
#  804,
#  803,
#  801,
#  800,
#  799,
#  798,
#  797,
#  795,
#  794,
#  793,
#  792,
#  791,
#  790,
#  789,
#  788,
#  787,
#  786,
#  785,
#  784,
#  783,
#  782,
#  781,
#  779,
#  778,
#  777,
#  776,
#  775,
#  772,
#  771,
#  770,
#  769,
#  768,
#  767,
#  766,
#  765,
#  764,
#  763,
#  762,
#  761,
#  758,
#  756,
#  754,
#  753,
#  749,
#  748,
#  747,
#  746,
#  745,
#  742,
#  741,
#  738,
#  736,
#  735,
#  734,
#  733,
#  732,
#  731,
#  730,
#  729,
#  727,
#  724,
#  723,
#  721,
#  720,
#  719,
#  718,
#  717,
#  716,
#  715,
#  714,
#  713,
#  711,
#  710,
#  709,
#  708,
#  707,
#  706,
#  705,
#  704,
#  703,
#  702,
#  700,
#  699,
#  698,
#  697,
#  695,
#  690,
#  689,
#  687,
#  686,
#  685,
#  684,
#  683,
#  682,
#  681,
#  680,
#  679,
#  678,
#  677,
#  676,
#  675,
#  673,
#  672,
#  671,
#  670,
# ...

# %%
word_table = pd.read_csv("/gdrive/My Drive/att_table_서울_1.csv", delimiter=",",encoding='utf-8')

# %%
for i in de:
  print(word_table['name'][i])
# Out:
# 한상수자수박물관
# 간송 미술관
# 마콘도
# 비보이를 사랑한 발레리나
# 칠궁
# 남인사 마당
# 육군 사관학교
# 아크앤북 - 시청점
# 더 방갈로
# 롯데 불한증막 사우나
# 한류스타거리
# 팬시스튜디오
# 한국 지역정보 센터
# 유니온볼링장
# 남산타운문화체육센터
# 부기우기
# 윈터프렌드
# 북촌 동양 문화 박물관
# 그린월
# CGV 여의도
# 클럽 베라
# 메가박스 목동
# 구러시아 공사관
# 디보 빌리지
# 동대문마사지
# K 리그 오피셜 스토어
# 풍림24시불가마사우나
# BK성형박물관
# 엠플라자
# 시몬느 핸드백 박물관
# 로봇 박물관
# VR스테이션 - 강남점
# 퀸마마마켓
# 한남볼링센타
# 잔쿠라 아트스페이스
# 퀸마마마켓
# 10 꼬르소 꼬모
# CGV 압구정점
# 헐리우드 그릴
# 호림아트센터 신사분관
# 한남볼링센타
# 롯데시네마 월드타워
# 케이메모리즈
# 현대시티아울렛 - 동대문점
# 쎈토이뮤지엄&쇼룸
# 명동황금사우나
# 블랙링크
# 나무 코리아 트래블 - 당일 투어
# 족도 마사지
# Kim's Travel - 당일 투어
# Gana Art Gallery
# 타요 키즈카페 은평뉴타운점
# 코리얼트립
# 레솔베르 시가샵 & 시가라운지
# 스매싱볼
# 한국의 집
# CGV 홍대
# 이화교복
# 한성 백제 박물관
# 쿠킹 난타
# 서울이스케이프룸 인천부평점
# 소울 트레인 빈티지 뮤직 라운지
# 뱀부테라피
# 라움 케이스타 스파
# 행궁길
# 이츠미 포토 스튜디오
# 레이크사우나
# 고은피부관리실
# 답동 성바오로 성당
# 광교호수공원
# 신구대학 식물원
# 오늘도 고양이
# 히마와리 마사지 & 카페
# 브이알존 강남점
# 약손명가 본점
# 올림피아 사우나
# 서울피부비만센터 스킨앤슬림
# 브이알존 홍대점
# 동대문지하쇼핑센터
# 뷰티플렉스 명동
# 동명사
# 선인상가
# 소반 코리안 쿠킹클래스
# 유진의 키친
# 아이러브한식
# 꽃같은한복
# VIP 트랜스퍼스 코리아
# 에이치엠케이트레블 (힐링모먼코리아)
# ...

# %%
loid = word_table['loid']
id1 = word_table['id']
name1 = word_table['name']
star = word_table['star']
num = word_table['num']
ttype = word_table['type']

# %%
for i in de:
    del loid[i]
    del id1[i]
    del name1[i]
    del star[i]
    del num[i]
    del ttype[i]

# %%
list2 = [loid,id1,name1,star,num,ttype]
rdf = pd.DataFrame(list2)
rdf=rdf.T
rdf.columns = ['loid','id','name','star','num','type']
rdf
# Out:
#         loid        id             name star    num         type
# 0     294197   1169465          N 서울 타워   40   9452     전망대 & 타워
# 1     294197   2194168            서울메트로   45  12703     공공 교통시스템
# 2    2024866   2041648            서울대공원   45    267           가든
# 6     294197   1046419              청계천   45   3941    유서 깊은 산책로
# 7    2024866   1868571             서울랜드   40    127  놀이공원 & 테마파크
# ..       ...       ...              ...  ...    ...          ...
# 885   294197   6941859      나비 에스테틱 논현점   50      1        요리 교실
# 886   294197  13954672           박스스튜디오   50      4      역사적인 장소
# 887   294197   4095561       숙명여자대학교박물관   50      8     조깅로 & 트랙
# 888   294197   3727478  와우코리아투어 - 당일 투어   45      4        아트뮤지엄
# 889   294197    592502       지구촌 민속 박물관   45      6     기타 야외 활동
#
# [281 rows x 6 columns]

# %%
 rdf.to_csv("final_att_table_서울.csv",index=False, encoding = 'utf-8')

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
rdf.to_csv('/gdrive/My Drive/final_att_table_서울.csv',index=False,encoding='utf-8')
# !ls /gdrive/My\ Drive/
# Out:
#  포트폴리오	      'Colab Notebooks'		  inmun_table.csv
# '제목없는 폴더'        data			  leports_table.csv
#  att_table_서울1.csv   final_att_table_서울.csv   nature_table.csv

# %%
import pandas as pd
word_table = pd.read_csv("/gdrive/My Drive/final_att_table_서울.csv", delimiter=",",encoding='utf-8')

# %%
word = word_table['name']
import re
word2 = []
for i in word:
    word2.append(i.replace(' ',''))

# %%
len(word)
# Out:
# 281

# %%
word2[0]='남산서울타워'

# %%
## word2에서 Tour API에 없는 관광지 제거 

for i in de:
  del word[i]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-77-6ce521143acb> in <module>()
#       2
#       3 for i in de:
# ----> 4   del word2[i]
#       5
#
# IndexError: list assignment index out of range

# %%
len(word2)
# Out:
# 281

# %%
word[0] = '남산서울타워'
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
del word[0]

# %%
## 제거 후 남은 관광지 정보를 Tour API에서 다시 불러오기

import requests
import json

data = []
contentid = []
addres = []
title = []

apikey = 'TFwdrWOmSyEFgY5tQ9oQke3Um450%2BfBGf0pwLunWtAAX16Cd%2Fb3zns%2BzgI67JhGlkbEuLXXfFbvK3M9obj8CBQ%3D%3D'
try:
  for i in word[0]:
      
      api=('http://api.visitkorea.or.kr/openapi/service/rest/KorService/searchKeyword?ServiceKey='+apikey+'&keyword={}&MobileOS=ETC&MobileApp=AppTest&_type=json').format(i)

    # dict2 = json.loads(json_val)
      r = requests.get(api)
      all_data = json.loads(r.text)
      data.append(all_data)
except:
  pass

# %%
all_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0cd65f1f8801> in <module>()
# ----> 1 all_data
#
# NameError: name 'all_data' is not defined

# %%
import requests
import json

data2 = []
contentid2 = []
addres2 = []
title2 = []

apikey = 'slRBmmH1bnn5k5JrVSIOZTtcwaaLogLUgRmgUgmeFLfAG0kdXYpY0A/WLlULnGXGubqwARlwvffhArbMqKdyhg=='
try:
  for i in word[0]:
      
      api=('http://api.visitkorea.or.kr/openapi/service/rest/KorService/searchKeyword?ServiceKey='+apikey+'&keyword={}&MobileOS=ETC&MobileApp=AppTest&_type=json').format(i)

    # dict2 = json.loads(json_val)
      r = requests.get(api)
      all_data = json.loads(r.text)
      data2.append(all_data)
except:
  pass

# %%
data2
# Out:
# []

# %%
j=0
type(data[j]['response']['body']['items']['item'])
# Out:
# list

# %%
#data[1]['response']['body']['items']['item']
type(data[0]['response']['body']['items']['item'])
# Out:
# list

# %%
su = []
for i in range(len(data)):
  su.append(i)

# %%
## 리스트에 Tour API 의 정보 저장

cat1 = []
cat2 = []
cat3 = []
contentid = []
title = []
xmap = []
ymap = []
areacode = []

for j in su:
    if type(data[j]['response']['body']['items']['item']) is list:
      cat1.append(data[j]['response']['body']['items']['item'][0]['cat1'])
      cat2.append(data[j]['response']['body']['items']['item'][0]['cat2'])
      cat3.append(data[j]['response']['body']['items']['item'][0]['cat3'])
      contentid.append(data[j]['response']['body']['items']['item'][0]['contentid'])
      title.append(data[j]['response']['body']['items']['item'][0]['title'])
      xmap.append(data[j]['response']['body']['items']['item'][0]['mapx'])
      ymap.append(data[j]['response']['body']['items']['item'][0]['mapy'])
      
    else:
      cat1.append(data[j]['response']['body']['items']['item']['cat1'])
      cat2.append(data[j]['response']['body']['items']['item']['cat2'])
      cat3.append(data[j]['response']['body']['items']['item']['cat3'])
      contentid.append(data[j]['response']['body']['items']['item']['contentid'])
      title.append(data[j]['response']['body']['items']['item']['title'])
      xmap.append(data[j]['response']['body']['items']['item']['mapx'])
      ymap.append(data[j]['response']['body']['items']['item']['mapy'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-bc52c4885f72> in <module>()
#      11
#      12 for j in su:
# ---> 13     if type(data[int(j)]['response']['body']['items']['item']) is list:
#      14       cat1.append(data[j]['response']['body']['items']['item'][0]['cat1'])
#      15       cat2.append(data[j]['response']['body']['items']['item'][0]['cat2'])
#
# TypeError: string indices must be integers

# %%
data
# Out:
# [{'response': {'body': {'items': {'item': [{'addr1': '서울특별시 용산구 남산공원길 105',
#        'addr2': '(용산동2가)',
#        'areacode': 1,
#        'booktour': 0,
#        'cat1': 'A02',
#        'cat2': 'A0205',
#        'cat3': 'A02050200',
#        'contentid': 126535,
#        'contenttypeid': 12,
#        'createdtime': 20021031000000,
#        'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/30/2477030_image2_1.jpg',
#        'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/30/2477030_image2_1.jpg',
#        'mapx': 126.9876206116,
#        'mapy': 37.5516394747,
#        'mlevel': 6,
#        'modifiedtime': 20200423101331,
#        'readcount': 99354,
#        'sigungucode': 21,
#        'title': '남산서울타워'},
#       {'addr1': '서울특별시 용산구 남산공원길 105',
#        'addr2': '(용산동2가)',
#        'areacode': 1,
#        'booktour': 0,
#        'cat1': 'A02',
#        'cat2': 'A0203',
#        'cat3': 'A02030200',
#        'contentid': 2435104,
#        'contenttypeid': 12,
# ...

# %%
list2 = [id1,cat1,cat2,cat3,contentid,title,xmap,ymap]
rdf = pd.DataFrame(list2)
rdf=rdf.T
rdf.columns = ['id','cat1','cat2','cat3','contentid','title','mapx','mapy']
rdf

# %%
 rdf.to_csv("2_att_table_서울.csv",index=False, encoding = 'utf-8')

# %%
import requests
import json

# %%
def load_data(corp_code):
    
    ### 기업개황 요청 url
    url = "https://opendart.fss.or.kr/api/company.json?crtfc_key=" +'02c190bf4a27db86defd39afd0c48183dbff1d2c'+"&corp_code=" +corp_code


    ### HTTP 요청
    r = requests.get(url)
     
    ### 요청한 데이터는 json형태이기 때문에 json으로 읽어줍니다.
    company_data = r.json()

    ### 기업개황을 요청했을 때 기업개황에 대한 자료를 반환합니다.
    return company_data

# %%
company_list_1 = [] 
for i in range(10):
    company_dict = load_data('00126380')
    
    ### list 변경할것
    company_list_1.append(company_dict)

# %%
company_list_1[0]
# Out:
# {'acc_mt': '12',
#  'adres': '경기도 수원시 영통구  삼성로 129 (매탄동)',
#  'bizr_no': '1248100998',
#  'ceo_nm': '김기남, 김현석, 고동진',
#  'corp_cls': 'Y',
#  'corp_code': '00126380',
#  'corp_name': '삼성전자(주)',
#  'corp_name_eng': 'SAMSUNG ELECTRONICS CO,.LTD',
#  'est_dt': '19690113',
#  'fax_no': '031-200-7538',
#  'hm_url': 'www.sec.co.kr',
#  'induty_code': '264',
#  'ir_url': '',
#  'jurir_no': '1301110006246',
#  'message': '정상',
#  'phn_no': '031-200-1114',
#  'status': '000',
#  'stock_code': '005930',
#  'stock_name': '삼성전자'}

# %%
from xml.etree import ElementTree as ET
from bs4 import BeautifulSoup as bs
import requests

# %%
url =  "https://opendart.fss.or.kr/api/corpCode.xml?crtfc_key=" +'02c190bf4a27db86defd39afd0c48183dbff1d2c'

res = requests.get(url)
soup = bs(res.content,'html.parser')
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.

# %%
# -*- coding: utf-8 -*-
from urllib.request import urlopen
from zipfile import ZipFile
from io import BytesIO
from bs4 import BeautifulSoup

url = "https://opendart.fss.or.kr/api/corpCode.xml?crtfc_key=" +'02c190bf4a27db86defd39afd0c48183dbff1d2c'


resp = urlopen(url)

# 수신된 resp의 bytes를 Buffer에 쌓고 zip file을 로드한다.
with ZipFile(BytesIO(resp.read())) as zf:
  file_list = zf.namelist()
  while len(file_list) > 0:
    file_name = file_list.pop()
    corpCode = zf.open(file_name).read().decode()
    break

# XML 데이터 파싱
soup = BeautifulSoup(corpCode, 'html.parser')

# %%
soup
# Out:
# Output hidden; open in https://colab.research.google.com to view.
